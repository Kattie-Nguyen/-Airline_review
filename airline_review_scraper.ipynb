# %% [markdown]
# # Web scraping

# %% [markdown]
# ## Scraping data from Skytrax

# %% [markdown]
# Navigate to this link: https://www.airlinequality.com/airline-reviews/air-canada you will see this data.
# Now, we can use Python and BeautifulSoup to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import csv
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time

# %%
# Base URL for Air Canada reviews
url = "https://www.airlinequality.com/airline-reviews/air-canada"

# Initialize list to store review data
data = []

# %%
# Pagination settings
page_num = 1
max_pages = 20
page_size = 100  # Number of reviews per page

while page_num <= max_pages:
    paginated_url = f"{url}/page/{page_num}/?sortby=post_date%3ADesc&pagesize={page_size}"

    print(f"🔍 Scraping page {page_num}...")

    # Send HTTP request
    response = requests.get(paginated_url, headers={'User-Agent': 'Mozilla/5.0'})

    # Check if request is successful
    if response.status_code != 200:
        print(f"❌ Failed to retrieve page {page_num}")
        break
    # Parse HTML content
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all review articles
    reviews = soup.find_all("article", {"itemprop": "review"})

    for review in reviews:
        title = review.find("h2",class_ = "text_header").text.replace("\n", " ")
        sub_header = review.find("h3",class_ = "text_sub_header").text.replace("\n", " ")
        content = review.find("div",class_ = "text_content").text.replace("\n", " ")

        # Extract rating from class attribute
        rating_tag = review.find("div", itemprop="reviewRating")
        if rating_tag:
            rating_value = rating_tag.find("span", itemprop="ratingValue")
            if rating_value:
                rating = rating_value.text.strip()

        # Extract date
        date = review.find("time").text.strip() if review.find("time") else "No Date"



        # Store data
        data.append([date, title, sub_header, content, rating])

    print(f"✅ Collected {len(data)} total reviews so far...")
    # Move to next page
    page_num += 1

    # Pause to avoid getting blocked
    time.sleep(2)
# Out:
# 🔍 Scraping page 1...
# ✅ Collected 100 total reviews so far...
# 🔍 Scraping page 2...
# ✅ Collected 200 total reviews so far...
# 🔍 Scraping page 3...
# ✅ Collected 300 total reviews so far...
# 🔍 Scraping page 4...
# ✅ Collected 400 total reviews so far...
# 🔍 Scraping page 5...
# ✅ Collected 500 total reviews so far...
# 🔍 Scraping page 6...
# ✅ Collected 600 total reviews so far...
# 🔍 Scraping page 7...
# ✅ Collected 700 total reviews so far...
# 🔍 Scraping page 8...
# ✅ Collected 800 total reviews so far...
# 🔍 Scraping page 9...
# ✅ Collected 900 total reviews so far...
# 🔍 Scraping page 10...
# ✅ Collected 1000 total reviews so far...
# 🔍 Scraping page 11...
# ✅ Collected 1100 total reviews so far...
# 🔍 Scraping page 12...
# ✅ Collected 1200 total reviews so far...
# 🔍 Scraping page 13...
# ✅ Collected 1300 total reviews so far...
# 🔍 Scraping page 14...
# ✅ Collected 1400 total reviews so far...
# 🔍 Scraping page 15...
# ✅ Collected 1500 total reviews so far...
# 🔍 Scraping page 16...
# ✅ Collected 1600 total reviews so far...
# 🔍 Scraping page 17...
# ✅ Collected 1700 total reviews so far...
# 🔍 Scraping page 18...
# ✅ Collected 1800 total reviews so far...
# 🔍 Scraping page 19...
# ✅ Collected 1900 total reviews so far...
# 🔍 Scraping page 20...
# ✅ Collected 2000 total reviews so far...

# %%
df = pd.DataFrame(data, columns=["Date", "Overall", "Reviewer Info", "Review", "Rating"])
df.replace(re.compile(r'\s*✅ Trip Verified \|\s*'), '', inplace=True)
df.replace(re.compile(r'\s*✅ Verified Review \|\s*'), '', inplace=True)
df.head(20)
# Out:
#                   Date                                       Overall  \
# 0    23rd January 2025                    "no help or options given"
# 1    21st January 2025                "always had a good experience"
# 2    17th January 2025   “Now they are refusing to give the refund!”
# 3    16th January 2025  "experience at check-in one of the worst"\r
# 4    16th January 2025             “What I can truly call a win win”
# 5   22nd December 2024               "nearly 1.5hrs to serve drinks"
# 6   21st December 2024                         "everyone was rushed"
# 7   19th December 2024                 "nothing short of a disaster"
# 8   15th December 2024       "business class service is outstanding"
# 9   15th December 2024                    "I am deeply disappointed"
# 10  10th December 2024      “an utter disaster from start to finish”
# 11   6th December 2024                             “a misery to fly”
# 12   2nd December 2024                      "my flight was changed"
# 13  28th November 2024                   “rude, uncooperative staff”
# 14  27th November 2024             "worst online booking experience"
# 15  23rd November 2024                "grumpy service, late flights"
# 16  19th November 2024                 "downgraded to Economy Class"
# 17  17th November 2024                          "Missed connections"
# 18  16th November 2024                        “They just don’t care”
# 19  12th November 2024              "disappointed by the experience"
#
#                                         Reviewer Info  \
# 0               R Heale (Australia) 23rd January 2025
# 1                T Chrones (Canada) 21st January 2025
# 2             Cinimol Nair (Canada) 17th January 2025
# 3                 M Erinaj (Canada) 16th January 2025
# 4            Paul Tyrrell (Ireland) 16th January 2025
# 5                E Han (Singapore) 22nd December 2024
# 6                 T Gayan (Canada) 21st December 2024
# 7     Sariah DeGarmo (United States) 19th December...
# 8      Steve Pilibbossian (Canada) 15th December 2024
# 9          E Doyle (United States) 15th December 2024
# 10              S Dawes (Portugal) 10th December 2024
# 11               T Gregory (Canada) 6th December 2024
# 12               S Malerri (Canada) 2nd December 2024
# 13           SS Shirodkar (Canada) 28th November 2024
# 14            Wajiha Shaw (Canada) 27th November 2024
# 15        Varnya Bromilow (Canada) 23rd November 2024
# 16               L Han (Australia) 19th November 2024
# 17      Colby Hunt (United States) 17th November 2024
# 18         Glenn Christie (Canada) 16th November 2024
# 19    Syed Muhammad Ammar (Canada) 12th November 2024
#
#                                                Review Rating
# 0   Delayed hours, boarded the plane and then wait...      1
# 1   Not Verified |  Have flown with Air Canada man...     10
# 2   I booked a bulkhead seat online so that I coul...      1
# 3   My husband and I had an extremely distressing ...      1
# 4   I flew with them last August. There was a prob...     10
# 5   Star alliance gold traveller, flew on many Sta...      1
# 6   I've flown air Canada many times, its better t...      2
# 7   Not Verified |  I recently flew with Air Canad...      1
# 8   I absolutely love Air Canada. Their internatio...     10
# 9   One of the flight attendants servicing the bac...      1
# 10  Oh, Air Canada, where do I begin? If you’re lo...      2
# 11  This Airline is a ripoff and a misery to fly. ...      1
# 12  I purchased my ticket together with my husband...      2
# 13  Not Verified | Worst airline and rude, uncoope...      1
# 14  Not Verified | Air Canada worst online booking...      1
# 15  Being Canadian, I have flown with this airline...      3
# 16  I booked a Business Class ticket with my paren...      1
# 17  Absolutely horrible airline. Missed connection...      1
# 18  Not Verified | A horrible airline. I have trie...      2
# 19  I recently traveled with Air Canada, and I’m e...      1

# %%
# Save to csv
df.to_csv("air_canada_reviews.csv")

# %%
sentiment_analysis_df=df.drop(["Date", "Overall", "Reviewer Info", "Rating"], axis=1)
sentiment_analysis_df
# Out:
#                                                  Review
# 0     Delayed hours, boarded the plane and then wait...
# 1     Not Verified |  Have flown with Air Canada man...
# 2     I booked a bulkhead seat online so that I coul...
# 3     My husband and I had an extremely distressing ...
# 4     I flew with them last August. There was a prob...
# ...                                                 ...
# 1995  I went out of my way to take the new Air Canad...
# 1996  Even on this very short 65 min flight from New...
# 1997  As a UK expat, I've done this route (YVR -LHR)...
# 1998  Toronto to Vancouver and back. Outbound I had ...
# 1999  I just wanted to recount the excellent custome...
#
# [2000 rows x 1 columns]

# %%
# Save to csv
sentiment_analysis_df.to_csv("sentiment_analysis.csv")
